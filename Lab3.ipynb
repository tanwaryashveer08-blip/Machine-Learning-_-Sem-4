# %% [markdown]
# <a href="https://colab.research.google.com/github/tanwaryashveer08-blip/Machine-Learning-_-Sem-4/blob/main/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
np.random.seed(45)
x = np.random.rand(4000,1) *100

# %%
print(x)
# Out:
# [[98.90115135]
#  [54.95447268]
#  [28.1447302 ]
#  ...
#  [30.34103641]
#  [10.34359508]
#  [64.67186145]]

# %%
Y = 3.5 * x + np.random.randn(4000, 1) * 20

# %%
print(Y)
# Out:
# [[341.54830307]
#  [204.60377316]
#  [115.06416813]
#  ...
#  [103.9166256 ]
#  [ 24.86560533]
#  [225.66528121]]

# %%
model = LinearRegression()
model.fit(x, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(x, Y)

# Labels and title
plt.xlabel("x values")
plt.ylabel("Y values")
plt.title("Scatter Plot between x and Y")

# Show plot
plt.show()

# %%
x = np.random.rand(4000)   # 50 random values between 0 and 1
Y = np.random.rand(4000)

# Calculate correlation
correlation = np.corrcoef(x, Y)[0, 1]

print("Correlation between X and Y:", correlation)
# Out:
# Correlation between X and Y: 0.0019978860577947156

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Re-define x and Y, and fit the model, as previous cells were not executed
np.random.seed(45)
x = np.random.rand(4000,1) *100
Y = 3.5 * x + np.random.randn(4000, 1) * 20

model = LinearRegression()
model.fit(x, Y)

Y_pred = model.predict(x)
plt.figure(figsize=(8,6))
plt.scatter(x, Y, color='blue', label='Data Points')
plt.plot(x, Y_pred, color='red', linewidth=2, label='Regression Line')
plt.title('Linear Regression on Random Dataset')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()
